# %% [markdown]
# <a href="https://colab.research.google.com/github/YawenZhao0218/YawenZhao0218.github.io/blob/main/host_localization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip output.zip
# Out:
# Archive:  output.zip
#    creating: output/
#   inflating: __MACOSX/._output
#    creating: output/cn/
#   inflating: __MACOSX/output/._cn
#    creating: output/sg/
#   inflating: __MACOSX/output/._sg
#    creating: output/cn/images/
#   inflating: __MACOSX/output/cn/._images
#   inflating: output/cn/cn_index.json
#   inflating: __MACOSX/output/cn/._cn_index.json
#   inflating: output/cn/cn_all_profiles.json
#   inflating: __MACOSX/output/cn/._cn_all_profiles.json
#    creating: output/cn/profiles/
#   inflating: __MACOSX/output/cn/._profiles
#    creating: output/sg/images/
#   inflating: __MACOSX/output/sg/._images
#   inflating: output/sg/sg_index.json
#   inflating: __MACOSX/output/sg/._sg_index.json
#   inflating: output/sg/sg_all_profiles.json
#   inflating: __MACOSX/output/sg/._sg_all_profiles.json
#    creating: output/sg/profiles/
#   inflating: __MACOSX/output/sg/._profiles
#   inflating: output/cn/images/HL_0287.png
#   inflating: __MACOSX/output/cn/images/._HL_0287.png
# ...

# %%
# !unzip high_level_profiles.zip
# Out:
# unzip:  cannot find or open high_level_profiles.zip, high_level_profiles.zip.zip or high_level_profiles.zip.ZIP.

# %%
# %cd /content/host_localization/
# Out:
# /content/host_localization

# %%
# !rm -rf /content/host_localization/__MACOSX/
